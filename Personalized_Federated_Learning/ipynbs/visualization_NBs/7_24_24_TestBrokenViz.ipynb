# %%
import numpy as np
import h5py
import torch
import os
import matplotlib.pyplot as plt

# %%
general_results_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results"
fedavg_filename = "FedAvg_test.h5"

directory_str = "07-24_20-34_FedAvg_LinRegr5_kfoldNone"
h5_path = os.path.join(general_results_path, directory_str, fedavg_filename)
with h5py.File(h5_path, 'r') as f:
    a_group_key = list(f.keys())[0]
    fedavg_val_train_loss = f['rs_train_loss'][()]
    fedavg_val_test_loss = f['rs_test_loss'][()]
    
plt.plot(range(len(fedavg_val_train_loss)), fedavg_val_train_loss, label="Train")
plt.plot(range(len(fedavg_val_test_loss)), fedavg_val_test_loss, label="Test")
plt.title("FedAvg Debugging Run")
plt.xlabel("Epoch Or Iteration?")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.plot(range(len(fedavg_val_train_loss)), fedavg_val_train_loss, label="Train")
plt.title("FedAvg Train Loss Curve")
plt.xlabel("Epoch Or Iteration?")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.plot(range(len(fedavg_val_test_loss)), fedavg_val_test_loss, label="Test")
plt.title("FedAvg Test Loss Curve")
plt.xlabel("Epoch Or Iteration?")
plt.ylabel("Loss")
plt.legend()
plt.show()
