# %%
import numpy as np
import h5py
import torch
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## H5 Files

# %%
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\first_success"
pfsr1 = r"mdHM_08-07_18-06_cphs_Local_test_0.h5"
#pfsr2 = r"mdHM_08-07_15-36_cphs_Local_test_0.h5"

with h5py.File(os.path.join(h5_path, pfsr1), 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("KEYS")
    print("Keys: %s" % f.keys())
    print()
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    print("a_group_key AKA list(f.keys())[0]")
    print(a_group_key)
    print("--------------------------------------")
    print()

    # get the object type for a_group_key: usually group or dataset
    #print(type(f[a_group_key])) 

    print("COST_FUNC_TUPLES_BY_CLIENT")#cost_func_tuples_by_client
    # If a_group_key is a group name, 
    # this gets the object names in the group and returns as a list
    data = list(f[a_group_key])
    print("Data AKA list(f[a_group_key])")
    print(data)
    print()

    # preferred methods to get dataset values:
    #ds_obj = f[a_group_key]      # returns as a h5py dataset object
    #ds_arr = f[a_group_key][()]  # returns as a numpy array
    
    group = f[a_group_key]
    print("Group AKA f[a_group_key]")
    print(group)
    print()
    #dataset = group['dataset_name']
    #data_array = group[()]
    specific_member = group['ClientID0'][()]
    print(type(specific_member))
    print(specific_member)
    print("--------------------------------------")
    print()
    
    print("GRADIENT_NORM_LOG")
    grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
    grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]
    print("len() of grad_norm_log_Cli0")
    print(len(grad_norm_log_Cli0))
    print("--------------------------------------")
    print()
    
    print("RS_TRAIN_LOSS")
    rs_train_loss_GROUP = f['rs_train_loss']
    print(f"rs_train_loss_GROUP: {rs_train_loss_GROUP}")
    print("rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(rs_train_loss_GROUP[()])), rs_train_loss_GROUP[()])
    plt.title("rs_train_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Training Loss")
    plt.show()
    print("--------------------------------------")
    print()
    
    print("RS_TEST_LOSS")
    rs_test_loss_GROUP = f['rs_test_loss']
    print(f"rs_test_loss_GROUP: {rs_test_loss_GROUP}")
    print("rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(rs_test_loss_GROUP[()])), rs_test_loss_GROUP[()])
    plt.title("rs_test_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Test Loss")
    plt.show()
    #print("--------------------------------------")
    #print()
# Out:
# KEYS
# Keys: <KeysViewHDF5 ['cost_func_tuples_by_client', 'gradient_norm_lists_by_client', 'rs_test_loss', 'rs_train_loss']>
#
# a_group_key AKA list(f.keys())[0]
# cost_func_tuples_by_client
# --------------------------------------
#
# COST_FUNC_TUPLES_BY_CLIENT
# Data AKA list(f[a_group_key])
# ['ClientID0', 'ClientID1', 'ClientID10', 'ClientID11', 'ClientID12', 'ClientID13', 'ClientID2', 'ClientID3', 'ClientID4', 'ClientID5', 'ClientID6', 'ClientID7', 'ClientID8', 'ClientID9']
#
# Group AKA f[a_group_key]
# <HDF5 group "/cost_func_tuples_by_client" (14 members)>
#
# <class 'numpy.ndarray'>
# [[0.00015998 0.00031852 0.        ]]
# --------------------------------------
#
# GRADIENT_NORM_LOG
# len() of grad_norm_log_Cli0
# 101
# --------------------------------------
#
# RS_TRAIN_LOSS
# rs_train_loss_GROUP: <HDF5 dataset "rs_train_loss": shape (100,), type "<f8">
# rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.
# --------------------------------------
#
# ...

# %%
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\8-8_20-17_Local1000"
h5_file_name = r"cphs_Local_test.h5"

with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("KEYS")
    print("Keys: %s" % f.keys())
    print()
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    print("a_group_key AKA list(f.keys())[0]")
    print(a_group_key)
    print("--------------------------------------")
    print()

    # get the object type for a_group_key: usually group or dataset
    #print(type(f[a_group_key])) 

    print("COST_FUNC_TUPLES_BY_CLIENT")#cost_func_tuples_by_client
    # If a_group_key is a group name, 
    # this gets the object names in the group and returns as a list
    client_list = list(f[a_group_key])
    print("Data AKA list(f[a_group_key])")
    print(client_list)
    print()
    
    group = f[a_group_key]
    print("Group AKA f[a_group_key]")
    print(group)
    print()
    specific_member = group['ClientID0'][()]
    cost_funcs_comps_list = [group[clientid][()] for clientid in group]
    print(type(specific_member))
    print(specific_member)
    print("--------------------------------------")
    print()
    
    print("GRADIENT_NORM_LOG")
    grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
    grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]
    grad_norms_list = [grad_norm_log_GROUP[clientid][()] for clientid in group]
    print("len() of grad_norm_log_Cli0")
    print(len(grad_norm_log_Cli0))
    print("--------------------------------------")
    print()
    
    print("RS_TRAIN_LOSS")
    rs_train_loss_GROUP = f['rs_train_loss']
    train_loss_1000 = rs_train_loss_GROUP[()]
    print(f"rs_train_loss_GROUP: {rs_train_loss_GROUP}")
    print("rs_train_loss_GROUP is a numpy array with 1000 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(train_loss_1000)), train_loss_1000)
    plt.title("rs_train_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Training Loss")
    plt.show()
    print("--------------------------------------")
    print()
    
    print("RS_TEST_LOSS")
    rs_test_loss_GROUP = f['rs_test_loss']
    test_loss_1000 = rs_test_loss_GROUP[()]
    print(f"rs_test_loss_GROUP: {rs_test_loss_GROUP}")
    print("rs_test_loss_GROUP is a numpy array with 1000 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(test_loss_1000)), test_loss_1000)
    plt.title("rs_test_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Test Loss")
    plt.show()
    #print("--------------------------------------")
    #print()
# Out:
# KEYS
# Keys: <KeysViewHDF5 ['cost_func_tuples_by_client', 'gradient_norm_lists_by_client', 'rs_test_loss', 'rs_train_loss']>
#
# a_group_key AKA list(f.keys())[0]
# cost_func_tuples_by_client
# --------------------------------------
#
# COST_FUNC_TUPLES_BY_CLIENT
# Data AKA list(f[a_group_key])
# ['ClientID0', 'ClientID1', 'ClientID10', 'ClientID11', 'ClientID12', 'ClientID13', 'ClientID2', 'ClientID3', 'ClientID4', 'ClientID5', 'ClientID6', 'ClientID7', 'ClientID8', 'ClientID9']
#
# Group AKA f[a_group_key]
# <HDF5 group "/cost_func_tuples_by_client" (14 members)>
#
# <class 'numpy.ndarray'>
# [[9.20999298e-07 1.11146255e-05 0.00000000e+00]]
# --------------------------------------
#
# GRADIENT_NORM_LOG
# len() of grad_norm_log_Cli0
# 1001
# --------------------------------------
#
# RS_TRAIN_LOSS
# rs_train_loss_GROUP: <HDF5 dataset "rs_train_loss": shape (1000,), type "<f8">
# rs_train_loss_GROUP is a numpy array with 1000 entries. NO CLIENT BREAK UP.
# ...

# %%
#grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
#grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]

plt.scatter(range(len(grad_norm_log_Cli0)), grad_norm_log_Cli0)
plt.title("Gradient Norm For ClientID0")
plt.xlabel("Training Round")
plt.ylabel("Gradient Norm")
plt.show()

# %%
for idx, client in enumerate(client_list):
    # GROUP is closed since the hdf file is closed
    user_grad_norm = grad_norms_list[idx]
    plt.scatter(range(len(user_grad_norm)), user_grad_norm, label=str(idx))
plt.title("Gradient Norm For All Clients")
plt.xlabel("Training Round")
plt.ylabel("Gradient Norm")
plt.show()

# %% [markdown]
# ## FedAvg 100 Rounds

# %%
fedavg100_filepath = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_11-06_FedAvg100"
#cphs_FedAvg_test.h5

h5_path = fedavg100_filepath
h5_file_name = r"cphs_FedAvg_test.h5"

with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("KEYS")
    print("Keys: %s" % f.keys())
    print()
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    print("a_group_key AKA list(f.keys())[0]")
    print(a_group_key)
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    
    print("GRADIENT_NORM_LOG")
    grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
    grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]
    fedavg100_grad_norms_list = [grad_norm_log_GROUP[clientid][()] for clientid in group]
    print("len() of grad_norm_log_Cli0")
    print(len(grad_norm_log_Cli0))
    print("--------------------------------------")
    print()
    
    print("RS_TRAIN_LOSS")
    rs_train_loss_GROUP = f['rs_train_loss']
    fedavg100_train_loss = rs_train_loss_GROUP[()]
    print(f"rs_train_loss_GROUP: {rs_train_loss_GROUP}")
    print("rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(fedavg100_train_loss)), fedavg100_train_loss)
    plt.title("rs_train_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Training Loss")
    plt.show()
    print("--------------------------------------")
    print()
    
    print("RS_TEST_LOSS")
    rs_test_loss_GROUP = f['rs_test_loss']
    fedavg100_test_loss = rs_test_loss_GROUP[()]
    print(f"rs_test_loss_GROUP: {fedavg100_test_loss}")
    print("rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(fedavg100_test_loss)), fedavg100_test_loss)
    plt.title("rs_test_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Test Loss")
    plt.show()
    #print("--------------------------------------")
    #print()
# Out:
# KEYS
# Keys: <KeysViewHDF5 ['cost_func_tuples_by_client', 'gradient_norm_lists_by_client', 'rs_test_loss', 'rs_train_loss']>
#
# a_group_key AKA list(f.keys())[0]
# cost_func_tuples_by_client
# GRADIENT_NORM_LOG
# len() of grad_norm_log_Cli0
# 15
# --------------------------------------
#
# RS_TRAIN_LOSS
# rs_train_loss_GROUP: <HDF5 dataset "rs_train_loss": shape (101,), type "<f8">
# rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.
# --------------------------------------
#
# RS_TEST_LOSS
# rs_test_loss_GROUP: [0.00382492 0.00376374 0.00374781 0.00372028 0.00368546 0.00364049
#  0.0035505  0.00349989 0.00346695 0.00343524 0.00340632 0.00338585
#  0.00335369 0.00332827 0.0033047  0.00328508 0.00325565 0.00323475
#  0.00320775 0.00318195 0.00316525 0.00314272 0.00312447 0.0031077
#  0.00309029 0.00307469 0.00305762 0.00302596 0.00300489 0.00298878
#  0.00297728 0.00296906 0.00293249 0.0029201  0.00290945 0.00289468
# ...

# %% [markdown]
# ## FedAvg 100 Rounds, using subroutine

# %%
fedavg_subrtn_filepath = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_11-55_FedAvg100_cphs_subrtn"
#cphs_FedAvg_test.h5

h5_path = fedavg_subrtn_filepath
h5_file_name = r"cphs_FedAvg_test.h5"

with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("KEYS")
    print("Keys: %s" % f.keys())
    print()
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    print("a_group_key AKA list(f.keys())[0]")
    print(a_group_key)
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    
    print("GRADIENT_NORM_LOG")
    grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
    grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]
    fedavg100SR_grad_norms_list = [grad_norm_log_GROUP[clientid][()] for clientid in group]
    print("len() of grad_norm_log_Cli0")
    print(len(grad_norm_log_Cli0))
    print("--------------------------------------")
    print()
    
    print("RS_TRAIN_LOSS")
    rs_train_loss_GROUP = f['rs_train_loss']
    fedavg100SR_train_loss = rs_train_loss_GROUP[()]
    print(f"rs_train_loss_GROUP: {rs_train_loss_GROUP}")
    print("rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(fedavg100SR_train_loss)), fedavg100SR_train_loss)
    plt.title("rs_train_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Training Loss")
    plt.show()
    print("--------------------------------------")
    print()
    
    print("RS_TEST_LOSS")
    rs_test_loss_GROUP = f['rs_test_loss']
    fedavg100SR_test_loss = rs_test_loss_GROUP[()]
    print(f"rs_test_loss_GROUP: {rs_test_loss_GROUP}")
    print("rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(fedavg100SR_test_loss)), fedavg100SR_test_loss)
    plt.title("rs_test_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Test Loss")
    plt.show()
    #print("--------------------------------------")
    #print()
# Out:
# KEYS
# Keys: <KeysViewHDF5 ['cost_func_tuples_by_client', 'gradient_norm_lists_by_client', 'rs_test_loss', 'rs_train_loss']>
#
# a_group_key AKA list(f.keys())[0]
# cost_func_tuples_by_client
# GRADIENT_NORM_LOG
# len() of grad_norm_log_Cli0
# 15
# --------------------------------------
#
# RS_TRAIN_LOSS
# rs_train_loss_GROUP: <HDF5 dataset "rs_train_loss": shape (101,), type "<f8">
# rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.
# --------------------------------------
#
# RS_TEST_LOSS
# rs_test_loss_GROUP: <HDF5 dataset "rs_test_loss": shape (102,), type "<f8">
# rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.

# %% [markdown]
# ## Local 100 rounds, using subroutine

# %%
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_11-48_Local100_cphs_subrtn"
h5_file_name = r"cphs_Local_test.h5"

with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("KEYS")
    print("Keys: %s" % f.keys())
    print()
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    print("a_group_key AKA list(f.keys())[0]")
    print(a_group_key)
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    
    print("GRADIENT_NORM_LOG")
    grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
    grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]
    local100SR_grad_norms_list = [grad_norm_log_GROUP[clientid][()] for clientid in group]
    print("len() of grad_norm_log_Cli0")
    print(len(grad_norm_log_Cli0))
    print("--------------------------------------")
    print()
    
    print("RS_TRAIN_LOSS")
    rs_train_loss_GROUP = f['rs_train_loss']
    local100SR_train_loss = rs_train_loss_GROUP[()]
    print(f"rs_train_loss_GROUP: {rs_train_loss_GROUP}")
    print("rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(local100SR_train_loss)), local100SR_train_loss)
    plt.title("rs_train_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Training Loss")
    plt.show()
    print("--------------------------------------")
    print()
    
    print("RS_TEST_LOSS")
    rs_test_loss_GROUP = f['rs_test_loss']
    local100SR_test_loss = rs_test_loss_GROUP[()]
    print(f"rs_test_loss_GROUP: {rs_test_loss_GROUP}")
    print("rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(local100SR_test_loss)), local100SR_test_loss)
    plt.title("rs_test_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Test Loss")
    plt.show()
    #print("--------------------------------------")
    #print()
# Out:
# KEYS
# Keys: <KeysViewHDF5 ['cost_func_tuples_by_client', 'gradient_norm_lists_by_client', 'rs_test_loss', 'rs_train_loss']>
#
# a_group_key AKA list(f.keys())[0]
# cost_func_tuples_by_client
# GRADIENT_NORM_LOG
# len() of grad_norm_log_Cli0
# 101
# --------------------------------------
#
# RS_TRAIN_LOSS
# rs_train_loss_GROUP: <HDF5 dataset "rs_train_loss": shape (100,), type "<f8">
# rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.
# --------------------------------------
#
# RS_TEST_LOSS
# rs_test_loss_GROUP: <HDF5 dataset "rs_test_loss": shape (101,), type "<f8">
# rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.

# %% [markdown]
# ## Comparing use of Subroutine on results

# %%
plt.scatter(range(len(fedavg100SR_train_loss)), fedavg100SR_train_loss)
plt.scatter(range(len(fedavg100_train_loss)), fedavg100_train_loss)
plt.title("rs_train_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Training Loss")
plt.show()

plt.scatter(range(len(fedavg100SR_test_loss)), fedavg100SR_test_loss)
plt.scatter(range(len(fedavg100_test_loss)), fedavg100_test_loss)
plt.title("rs_test_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Test Loss")
plt.show()

# %% [markdown]
# > Minimal variation, appears to be due more so to random fluctuations such as which client was chosen.  Subroutine appear to slightly outperform but unclear that that would be because of the code as opposed to the data itself

# %% [markdown]
# > LOCAL

# %%
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\first_success"
pfsr1 = r"mdHM_08-07_18-06_cphs_Local_test_0.h5"

with h5py.File(os.path.join(h5_path, pfsr1), 'r') as f:
    a_group_key = list(f.keys())[0]
    data = list(f[a_group_key])
    group = f[a_group_key]
    
    rs_train_loss = f['rs_train_loss'][()]    
    rs_test_loss = f['rs_test_loss'][()]

# %%
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_13-41_Local100rerun"
pfsr1 = r"cphs_Local_test.h5"

with h5py.File(os.path.join(h5_path, pfsr1), 'r') as f:
    a_group_key = list(f.keys())[0]
    data = list(f[a_group_key])
    group = f[a_group_key]
    
    rs_train_loss_rerun = f['rs_train_loss'][()]    
    rs_test_loss_rerun = f['rs_test_loss'][()]

# %%
plt.scatter(range(len(rs_train_loss)), rs_train_loss)
plt.scatter(range(len(rs_train_loss_rerun)), rs_train_loss_rerun)
plt.scatter(range(len(local100SR_train_loss)), local100SR_train_loss)
plt.title("rs_train_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Training Loss")
plt.show()

plt.scatter(range(len(rs_test_loss)), rs_test_loss)
plt.scatter(range(len(rs_test_loss_rerun)), rs_test_loss_rerun)
plt.scatter(range(len(local100SR_test_loss)), local100SR_test_loss)
plt.title("rs_test_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Test Loss")
plt.show()

# %% [markdown]
# > Hmmm why is there the big drop now but before it was just a straight line? Subroutine issue, or did code changes between then and adding the subroutine cause this? Idk if it's good or bad. The gap is somewhat substantial but they are pretty close. More concerned about the different slopes at the beginning.
#
# > Coming back and rerunning my code shows that the Local100 rerun (no subroutine but with the most up to date code) also results in the same shape as the version with subroutine.  Interesting that there is so little variation (green completely covers orange). The original local plotted which is straight is the first success version. Tons of stuff has changed, I'm just gonna ignore the performance difference.

# %% [markdown]
# ## APFL

# %%
apfl100_filepath = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_15-08_APFL100"
#cphs_APFL_test.h5

h5_path = apfl100_filepath
h5_file_name = r"cphs_APFL_test.h5"

with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("KEYS")
    print("Keys: %s" % f.keys())
    print()
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    print("a_group_key AKA list(f.keys())[0]")
    print(a_group_key)
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    
    # DOESNT SAVE GRADIENT NORMS YET!!
    #print("GRADIENT_NORM_LOG")
    #grad_norm_log_GROUP = f['gradient_norm_lists_by_client']
    #grad_norm_log_Cli0 = grad_norm_log_GROUP['ClientID0'][()]
    #apfl100_grad_norms_list = [grad_norm_log_GROUP[clientid][()] for clientid in group]
    #print("len() of grad_norm_log_Cli0")
    #print(len(grad_norm_log_Cli0))
    #print("--------------------------------------")
    #print()
    
    print("RS_TRAIN_LOSS")
    rs_train_loss_GROUP = f['rs_train_loss']
    apfl100_train_loss = rs_train_loss_GROUP[()]
    print(f"rs_train_loss_GROUP: {rs_train_loss_GROUP}")
    print("rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(apfl100_train_loss)), apfl100_train_loss)
    plt.title("rs_train_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Training Loss")
    plt.show()
    print("--------------------------------------")
    print()
    
    print("RS_TEST_LOSS")
    rs_test_loss_GROUP = f['rs_test_loss']
    apfl100_test_loss = rs_test_loss_GROUP[()]
    print(f"rs_test_loss_GROUP: {rs_test_loss_GROUP}")
    print("rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.")
    plt.scatter(range(len(apfl100_test_loss)), apfl100_test_loss)
    plt.title("rs_test_loss (averaged over all clients)")
    plt.xlabel("Training Round")
    plt.ylabel("Test Loss")
    plt.show()
    #print("--------------------------------------")
    #print()
# Out:
# KEYS
# Keys: <KeysViewHDF5 ['rs_test_loss', 'rs_train_loss']>
#
# a_group_key AKA list(f.keys())[0]
# rs_test_loss
# RS_TRAIN_LOSS
# rs_train_loss_GROUP: <HDF5 dataset "rs_train_loss": shape (101,), type "<f8">
# rs_train_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.
# --------------------------------------
#
# RS_TEST_LOSS
# rs_test_loss_GROUP: <HDF5 dataset "rs_test_loss": shape (101,), type "<f8">
# rs_test_loss_GROUP is a numpy array with 100 entries. NO CLIENT BREAK UP.

# %% [markdown]
# # Comparing Algorithms

# %%
# LOCAL
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_10-12_Local100"
h5_file_name = r"cphs_Local_test.h5"
with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    a_group_key = list(f.keys())[0]
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    rs_train_loss_GROUP = f['rs_train_loss']
    local100_train_loss = rs_train_loss_GROUP[()]
    rs_test_loss_GROUP = f['rs_test_loss']
    local100_test_loss = rs_test_loss_GROUP[()]

# FEDVG
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_11-06_FedAvg100"
h5_file_name = r"cphs_FedAvg_test.h5"
with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    a_group_key = list(f.keys())[0]
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    rs_train_loss_GROUP = f['rs_train_loss']
    fedavg100_train_loss = rs_train_loss_GROUP[()]
    rs_test_loss_GROUP = f['rs_test_loss']
    fedavg100_test_loss = rs_test_loss_GROUP[()]
    
# APFL
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-09_15-08_APFL100"
h5_file_name = r"cphs_APFL_test.h5"
with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    a_group_key = list(f.keys())[0]
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    rs_train_loss_GROUP = f['rs_train_loss']
    apfl100_train_loss = rs_train_loss_GROUP[()]
    rs_test_loss_GROUP = f['rs_test_loss']
    apfl100_test_loss = rs_test_loss_GROUP[()]
    
# FEDMTL
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-10_21-03_FedMTL100"
h5_file_name = r"cphs_FedMTL_test.h5"
with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    a_group_key = list(f.keys())[0]
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    rs_train_loss_GROUP = f['rs_train_loss']
    fedmtl100_train_loss = rs_train_loss_GROUP[()]
    rs_test_loss_GROUP = f['rs_test_loss']
    fedmtl100_test_loss = rs_test_loss_GROUP[()]

# PFEDME
h5_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\results\08-10_20-54_pFedMe100"
h5_file_name = r"cphs_pFedMe_test.h5"
with h5py.File(os.path.join(h5_path, h5_file_name), 'r') as f:
    a_group_key = list(f.keys())[0]
    client_list = list(f[a_group_key])
    group = f[a_group_key]
    #print(group)
    rs_train_loss_GROUP = f['rs_train_loss_per']
    pfedme100_train_loss = rs_train_loss_GROUP[()]
    rs_test_loss_GROUP = f['rs_test_loss_per']
    pfedme100_test_loss = rs_test_loss_GROUP[()]

plt.plot(range(len(local100_train_loss)), local100_train_loss, label='Local')
plt.plot(range(len(fedavg100_train_loss)), fedavg100_train_loss, label='FedAvg')
plt.plot(range(len(apfl100_train_loss)), apfl100_train_loss, label='APFL')
plt.plot(range(len(fedmtl100_train_loss)), fedmtl100_train_loss, label='FedMTL')
plt.plot(range(len(pfedme100_train_loss)), pfedme100_train_loss, label='pFedMe')
plt.title("rs_train_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Training Loss")
plt.legend()
plt.show()

plt.plot(range(len(local100_test_loss)), local100_test_loss, label='Local')
plt.plot(range(len(fedavg100_test_loss)), fedavg100_test_loss, label='FedAvg')
plt.plot(range(len(apfl100_test_loss)), apfl100_test_loss, label='APFL')
plt.plot(range(len(fedmtl100_test_loss)), fedmtl100_test_loss, label='FedMTL')
plt.plot(range(len(pfedme100_test_loss)), pfedme100_test_loss, label='pFedMe')
plt.title("rs_test_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Test Loss")
plt.legend()
plt.show()

# %%
plt.plot(range(len(local100_train_loss)), local100_train_loss, label='Local')
plt.plot(range(len(fedavg100_train_loss)), fedavg100_train_loss, label='FedAvg')
#plt.plot(range(len(apfl100_train_loss)), apfl100_train_loss, label='APFL')
plt.plot(range(len(fedmtl100_train_loss)), fedmtl100_train_loss, label='FedMTL')
plt.plot(range(len(pfedme100_train_loss)), pfedme100_train_loss, label='pFedMe')
plt.title("rs_train_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Training Loss")
plt.legend()
plt.show()

plt.plot(range(len(local100_test_loss)), local100_test_loss, label='Local')
plt.plot(range(len(fedavg100_test_loss)), fedavg100_test_loss, label='FedAvg')
plt.plot(range(len(apfl100_test_loss)), apfl100_test_loss, label='APFL')
plt.plot(range(len(fedmtl100_test_loss)), fedmtl100_test_loss, label='FedMTL')
#plt.plot(range(len(pfedme100_test_loss)), pfedme100_test_loss, label='pFedMe')
plt.title("rs_test_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Test Loss")
plt.legend()
plt.show()

#plt.plot(range(len(local100_test_loss)), local100_test_loss, label='Local')
#plt.plot(range(len(fedavg100_test_loss)), fedavg100_test_loss, label='FedAvg')
#plt.plot(range(len(apfl100_test_loss)), apfl100_test_loss, label='APFL')
#plt.plot(range(len(fedmtl100_test_loss)), fedmtl100_test_loss, label='FedMTL')
plt.plot(range(len(pfedme100_test_loss)), pfedme100_test_loss, label='pFedMe')
plt.title("rs_test_loss (averaged over all clients)")
plt.xlabel("Training Round")
plt.ylabel("Test Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Models
# > Looking at the client models

# %%
client_models_folder = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\models\cphs\Local"
#client_0_local_client_model
file_prefix = r"\client_"
file_num = 0
file_suffix = r"_local_client_model.pt"

sample_path = client_models_folder + file_prefix + str(file_num) + file_suffix
print(sample_path)

model_list = [0]*14

print_models = False
if print_models:
    for i in range(14):
        path = client_models_folder + file_prefix + str(i) + file_suffix
        model_list[i] = torch.load(path) 
        print(model_list[i].weight)
        print()
        print()

# %%
models_path = r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\models\cphs\Local"
today1 = "08-08_12-07"
today2 = "08-08_12-56"
fsr = "First_Successful_Run"
pca = "PCA_On_08-07_18-06"

# %%
with h5py.File('../results/cphs_Local_test_0.h5', 'r') as f:
    print("Success1")
    print(list(f))
    data = f['rs_train_loss']
    print(len(data))
    print(np.array(data))

# %%
with h5py.File('../results/cphs_Local_test_0.h5', 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("Keys: %s" % f.keys())
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]

    # get the object type for a_group_key: usually group or dataset
    print(type(f[a_group_key])) 

    # If a_group_key is a group name, 
    # this gets the object names in the group and returns as a list
    data = list(f[a_group_key])

    # If a_group_key is a dataset name, 
    # this gets the dataset values and returns as a list
    data = list(f[a_group_key])
    # preferred methods to get dataset values:
    ds_obj = f[a_group_key]      # returns as a h5py dataset object
    ds_arr = f[a_group_key][()]  # returns as a numpy array

# %%
item_path = r'C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Personalized_Federated_Learning\models\cphs'
#torch.save(item, os.path.join(item_path, "client_" + str(self.id) + "_" + item_name + ".pt"))
#my_model_file = os.path.join(item_path, "client_" + str(self.id) + "_" + item_name + ".pt")
my_model_file = os.path.join(item_path, "Local_server.pt")

# Load the file
local_model = torch.load(my_model_file)

# Print the head of the file
print(local_model)

# %%
#for param in local_model.parameters():
#    print(param)
# or
print("Name: Param")
for name, param in local_model.named_parameters():
    print(f"{name}: {param}")
