# %%
import copy
import torch
import torch.nn as nn
import numpy as np
import random
import os
#import torch.nn.functional as F
from torch.utils.data import DataLoader
from sklearn import metrics

from sklearn.decomposition import PCA
from utils.custom_loss_class import CPHSLoss
from utils.custom_loss_class2 import CPHSLoss2
import matplotlib.pyplot as plt

from torch_linregr import cost_l2_torch, full_train_linregr_updates

# %%
import time
import pickle
from math import isnan

# %%
#class CPHSLoss(torch.nn.modules.loss._Loss):
#def __init__(self, F, D, V, learning_batch, lambdaF=0, lambdaD=1e-3, lambdaE=1e-6, Nd=2, Ne=64, return_cost_func_comps=False, verbose=False, dt=1/60, normalize_V=False) -> None:
#def forward(self, outputs, targets, my_model):

#self.loss = CPHSLoss(self.F, self.model.weight, self.V, self.F.size()[1], lambdaF=self.lambdaF, lambdaD=self.lambdaD, lambdaE=self.lambdaE, Nd=2, Ne=self.pca_channels, return_cost_func_comps=self.return_cost_func_comps)
#loss_value.backward()

# %%
# CLIENTBASE.PY
#self.loss = CPHSLoss(self.F, self.model.weight, self.V, self.F.size()[1], lambdaF=self.lambdaF, lambdaD=self.lambdaD, lambdaE=self.lambdaE, Nd=2, Ne=self.pca_channels, return_cost_func_comps=self.return_cost_func_comps)
#
#self.optimizer = torch.optim.SGD(self.model.parameters(), lr=self.learning_rate)
#self.learning_rate_scheduler = torch.optim.lr_scheduler.ExponentialLR(
#    optimizer=self.optimizer, 
#    gamma=args.learning_rate_decay_gamma
#)
#self.learning_rate_decay = args.learning_rate_decay

# %%
# CLIENTAVG.PY
#output = self.model(x)
#loss = self.loss(output, y, self.model)
#self.loss_log.append(loss.item())
#running_num_samples += x.size(0)
#self.optimizer.zero_grad()
#loss.backward()
#self.optimizer.step()

# %%
# TORCH_LINREGR.PY
# TRAIN MODEL
# reset gradient so it doesn't accumulate
#optimizer.zero_grad()
# forward pass and loss
#y_pred = model(torch.transpose(emg_streamed_batch, 0, 1))  # Why do I have to transpose again here... my original code didn't
# F, D, V, learning_batch
#if use_CPHSLoss:
#    criterion = CPHSLoss
#else:
#    criterion = cost_l2_torch
#loss = criterion(emg_streamed_batch, model.weight, V, emg_streamed_batch.shape[1], Ne=PCA_comps, lambdaF=lambdasFDE[0], lambdaD=lambdasFDE[1], lambdaE=lambdasFDE[2])  #, return_cost_func_comps=return_cost_func_comps)
# backward pass
#loss.backward(retain_graph=True)
# update weights
#optimizer.step()

# %% [markdown]
# # Load In Data And Params

# %%
with open(r"C:\Users\kdmen\Desktop\Research\personalization-privacy-risk\Data\continuous_full_data_block1.pickle", 'rb') as handle:
    #refs_block1, poss_block1, dec_vels_block1, int_vel_block1, emgs_block1, Ws_block1, Hs_block1, alphas_block1, pDs_block1, times_block1, conditions_block1 = pickle.load(handle)
    refs_block1, _, _, _, emgs_block1, _, _, _, _, _, _ = pickle.load(handle)
    
keys = ['METACPHS_S106', 'METACPHS_S107', 'METACPHS_S108', 'METACPHS_S109', 'METACPHS_S110', 'METACPHS_S111', 'METACPHS_S112', 'METACPHS_S113', 'METACPHS_S114', 'METACPHS_S115', 'METACPHS_S116', 'METACPHS_S117', 'METACPHS_S118', 'METACPHS_S119']
key_to_num = dict()
num_to_key = dict()
for idx, key in enumerate(keys):
    key_to_num[key] = idx
    num_to_key[idx] = key

num_conds = 8
num_channels = 64
num_updates = 19
cphs_starting_update = 10
update_ix = [0,  1200,  2402,  3604,  4806,  6008,  7210,  8412,  9614, 10816, 12018, 13220, 14422, 15624, 16826, 18028, 19230, 20432, 20769]

# %% [markdown]
# # Testing Basic PyTorch and SKLearn Linear Regression

# %% [markdown]
# ## From NB106

# %%
# Functioning params from NB101-106
lambdaF = 0
lambdaD = 1e-10
lambdaE = 1e-6
lambdasFDE=[lambdaF, lambdaD, lambdaE]
learning_rate = 0.0001

dt=1/60

#train/test split at update_ix[16]
cli0_cond1_traindata = torch.from_numpy(emgs_block1[keys[0]][0, :update_ix[16], :]).type(torch.float32)
cli0_cond1_trainlabels = torch.from_numpy(refs_block1[keys[0]][0, :update_ix[16], :]).type(torch.float32)
cli0_cond1_testdata = torch.from_numpy(emgs_block1[keys[0]][0, update_ix[16]:, :]).type(torch.float32)
cli0_cond1_testlabels = torch.from_numpy(refs_block1[keys[0]][0, update_ix[16]:, :]).type(torch.float32)

lower_bound = update_ix[10]
upper_bound = update_ix[11]
#s_temp = cli0_cond1_traindata[lower_bound:upper_bound]
#p_reference = torch.transpose(cli0_cond1_trainlabels[lower_bound:upper_bound], 0, 1)

# %% [markdown]
# ## Using CPHSLoss

# %%
cli0_cond1_traindata.shape
# Out:
# torch.Size([19230, 64])

# %%
cli0_cond1_trainlabels.shape
# Out:
# torch.Size([19230, 2])

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr
optimizer = torch.optim.SGD(untrained_model_FullData.parameters(), lr=learning_rate)

#train/test split at update_ix[16]
cli0_cond1_traindata = torch.from_numpy(emgs_block1[keys[0]][0, :update_ix[16], :]).type(torch.float32)
cli0_cond1_trainlabels = torch.from_numpy(refs_block1[keys[0]][0, :update_ix[16], :]).type(torch.float32)
cli0_cond1_testdata = torch.from_numpy(emgs_block1[keys[0]][0, update_ix[16]:, :]).type(torch.float32)
cli0_cond1_testlabels = torch.from_numpy(refs_block1[keys[0]][0, update_ix[16]:, :]).type(torch.float32)

#def full_train_linregr_updates(model, full_trial_input_data, full_trial_labels, 
#    learning_rate, lambdasFDE=[0, 1e-3, 1e-6], use_CPHSLoss=False, normalize_data=False, PCA_comps=64, 
#    num_iters_per_update=30, starting_update=10, use_full_input_data=False, stream_data_updates=True, 
#    dt=1/60, loss_log=None, verbose=False, verbose_norms=False, return_cost_func_comps=False, update_ix=...):
trained_model_FullData, loss_log_FullData = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=False, use_full_input_data=True, starting_update=0,
                                                                       use_CPHSLoss=True)

plt.plot(range(len(loss_log_FullData)), loss_log_FullData, linewidth=3)
plt.title("Training Loss On Nonstreamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss True; use_CPHSLoss2 False
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data True
# stream_data_updates False
# return_cost_func_comps False

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr

trained_model_streamed, loss_log_streamed = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=0,
                                                                       use_CPHSLoss=True)

plt.plot(range(len(loss_log_streamed)), loss_log_streamed, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss True; use_CPHSLoss2 False
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr

trained_model_streamed10, loss_log_streamed10 = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=10,
                                                                       use_CPHSLoss=True)

plt.plot(range(len(loss_log_streamed10)), loss_log_streamed10, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 10-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss True; use_CPHSLoss2 False
# normalize_emg False
# num_iters_per_update 30
# starting_update 10
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False

# %% [markdown]
# ## Using CPHLoss2

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr
optimizer = torch.optim.SGD(untrained_model_FullData.parameters(), lr=learning_rate)

#train/test split at update_ix[16]
cli0_cond1_traindata = torch.from_numpy(emgs_block1[keys[0]][0, :update_ix[16], :]).type(torch.float32)
cli0_cond1_trainlabels = torch.from_numpy(refs_block1[keys[0]][0, :update_ix[16], :]).type(torch.float32)
cli0_cond1_testdata = torch.from_numpy(emgs_block1[keys[0]][0, update_ix[16]:, :]).type(torch.float32)
cli0_cond1_testlabels = torch.from_numpy(refs_block1[keys[0]][0, update_ix[16]:, :]).type(torch.float32)

#def full_train_linregr_updates(model, full_trial_input_data, full_trial_labels, 
#    learning_rate, lambdasFDE=[0, 1e-3, 1e-6], use_CPHSLoss=False, normalize_data=False, PCA_comps=64, 
#    num_iters_per_update=30, starting_update=10, use_full_input_data=False, stream_data_updates=True, 
#    dt=1/60, loss_log=None, verbose=False, verbose_norms=False, return_cost_func_comps=False, update_ix=...):
trained_model_FullData, loss_log_FullData = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=False, use_full_input_data=True, starting_update=0,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_FullData)), loss_log_FullData, linewidth=3)
plt.title("Training Loss On Nonstreamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data True
# stream_data_updates False
# return_cost_func_comps False

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr

trained_model_streamed, loss_log_streamed = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=0,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_streamed)), loss_log_streamed, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr

trained_model_streamed10, loss_log_streamed10 = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=10,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_streamed10)), loss_log_streamed10, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 10-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 10
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False

# %% [markdown]
# ## Comparing Model and Matmul

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr
optimizer = torch.optim.SGD(untrained_model_FullData.parameters(), lr=learning_rate)

trained_model_FullData, loss_log_FullData = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, compare_model_and_matmul=True, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=False, use_full_input_data=True, starting_update=0,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_FullData)), loss_log_FullData, linewidth=3)
plt.title("Training Loss On Nonstreamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data True
# stream_data_updates False
# return_cost_func_comps False
#
# v_pred_model shape: torch.Size([19228, 2]);
#  vals[:5,:]: tensor([[-0.0926, -0.0384],
#         [-0.0926, -0.0384],
#         [-0.0926, -0.0384],
#         [ 4.1242,  1.8329],
#         [ 4.1242,  1.8329]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[11.1172, 18.5797],
#         [11.1172, 18.5797],
#         [11.1172, 18.5797],
#         [13.0092, 15.6251],
#         [13.0092, 15.6251]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([19228, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [4.2168, 1.8713],
#         [4.2168, 1.8713]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[11.2098, 18.6181],
#         [11.2098, 18.6181],
#         [11.2098, 18.6181],
#         [13.1018, 15.6635],
#         [13.1018, 15.6635]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([19229, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [4.2168, 1.8713],
#         [4.2168, 1.8713]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[11.2098, 18.6181],
#         [11.2098, 18.6181],
#         [11.2098, 18.6181],
#         [13.1018, 15.6635],
#         [13.1018, 15.6635],
#         [15.4722, 11.0960]], grad_fn=<SliceBackward0>)

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr

trained_model_streamed, loss_log_streamed = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, compare_model_and_matmul=True, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=0,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_streamed)), loss_log_streamed, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False
#
# v_pred_model shape: torch.Size([1199, 2]);
#  vals[:5,:]: tensor([[-0.0214,  0.0636],
#         [-0.0214,  0.0636],
#         [-0.0214,  0.0636],
#         [ 0.2544,  1.1357],
#         [ 0.2544,  1.1357]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-15.6642,  -1.2905],
#         [-15.6642,  -1.2905],
#         [-15.7845,   0.2538],
#         [-15.7845,   0.2538],
#         [-15.7845,   0.2538]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1199, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.2758, 1.0721],
#         [0.2758, 1.0721]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-15.6428,  -1.3542],
#         [-15.6428,  -1.3542],
#         [-15.7631,   0.1902],
#         [-15.7631,   0.1902],
#         [-15.7631,   0.1902]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1200, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.2758, 1.0721],
#         [0.2758, 1.0721]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-15.6428,  -1.3542],
#         [-15.6428,  -1.3542],
#         [-15.7631,   0.1902],
#         [-15.7631,   0.1902],
#         [-15.7631,   0.1902],
#         [-18.3928,   0.5646]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-17.5942,   1.2010],
#         [-17.5942,   1.2010],
#         [-16.4653,  -3.5506],
#         [-17.4931,  -1.0409],
#         [-16.5206,  -1.5323]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-2.0125, -3.4808],
#         [-2.0125, -3.4808],
#         [-6.5472,  5.0440],
#         [-6.5472,  5.0440],
#         [-6.5472,  5.0440]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-17.5728,   1.1374],
#         [-17.5728,   1.1374],
#         [-16.4439,  -3.6143],
#         [-17.4717,  -1.1045],
#         [-16.4992,  -1.5959]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-1.9912, -3.5445],
#         [-1.9912, -3.5445],
#         [-6.5258,  4.9803],
#         [-6.5258,  4.9803],
#         [-6.5258,  4.9804]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-17.5728,   1.1374],
#         [-17.5728,   1.1374],
#         [-16.4439,  -3.6143],
#         [-17.4717,  -1.1045],
#         [-16.4992,  -1.5959]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-1.9912, -3.5445],
#         [-1.9912, -3.5445],
#         [-6.5258,  4.9803],
#         [-6.5258,  4.9804],
#         [-6.5258,  4.9804],
#         [-6.5258,  4.9804]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-5.0820,  9.0443],
#         [-5.0820,  9.0443],
#         [-5.0873, 12.6700],
#         [-7.5417, 10.1423],
#         [-7.5417, 10.1423]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.6637, -3.6430],
#         [-5.6637, -3.6430],
#         [-4.2236, -3.3183],
#         [-4.2236, -3.3183],
#         [-3.5417, -4.1112]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-5.0606,  8.9807],
#         [-5.0606,  8.9807],
#         [-5.0659, 12.6064],
#         [-7.5204, 10.0787],
#         [-7.5204, 10.0787]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.6424, -3.7066],
#         [-5.6424, -3.7066],
#         [-4.2022, -3.3819],
#         [-4.2022, -3.3819],
#         [-3.5204, -4.1748]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-5.0606,  8.9807],
#         [-5.0606,  8.9807],
#         [-5.0659, 12.6064],
#         [-7.5204, 10.0787],
#         [-7.5204, 10.0787]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-5.6424, -3.7066],
#         [-5.6424, -3.7066],
#         [-4.2022, -3.3819],
#         [-4.2022, -3.3819],
#         [-3.5204, -4.1748],
#         [-3.5204, -4.1748]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-2.3564, -4.1109],
#         [-2.3564, -4.1109],
#         [-6.6631, -3.0099],
#         [-6.2320, -3.6546],
#         [-6.2320, -3.6546]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 1.2268, -7.4015],
#         [ 1.2268, -7.4015],
#         [ 0.2781, -6.8766],
#         [ 0.2781, -6.8766],
#         [ 2.6330, -7.4010]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-2.3351, -4.1745],
#         [-2.3351, -4.1745],
#         [-6.6418, -3.0735],
#         [-6.2107, -3.7182],
#         [-6.2107, -3.7182]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 1.2481, -7.4652],
#         [ 1.2481, -7.4652],
#         [ 0.2994, -6.9403],
#         [ 0.2994, -6.9403],
#         [ 2.6543, -7.4646]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-2.3351, -4.1745],
#         [-2.3351, -4.1745],
#         [-6.6418, -3.0735],
#         [-6.2107, -3.7182],
#         [-6.2107, -3.7182]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 1.2481, -7.4652],
#         [ 1.2481, -7.4652],
#         [ 0.2994, -6.9403],
#         [ 0.2994, -6.9403],
#         [ 2.6543, -7.4646],
#         [ 2.6543, -7.4646]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 3.9603, -7.2459],
#         [ 3.9603, -7.2459],
#         [ 5.4463, -6.5016],
#         [ 4.1916, -4.5985],
#         [ 4.1916, -4.5985]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.5633, -2.2467],
#         [-5.5633, -2.2467],
#         [ 0.7667, -3.6255],
#         [ 0.7667, -3.6255],
#         [ 1.3412, -4.4052]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 3.9816, -7.3096],
#         [ 3.9816, -7.3096],
#         [ 5.4676, -6.5653],
#         [ 4.2129, -4.6621],
#         [ 4.2129, -4.6621]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.5420, -2.3104],
#         [-5.5420, -2.3104],
#         [ 0.7880, -3.6891],
#         [ 0.7880, -3.6891],
#         [ 1.3625, -4.4689]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 3.9816, -7.3096],
#         [ 3.9816, -7.3096],
#         [ 5.4676, -6.5653],
#         [ 4.2129, -4.6621],
#         [ 4.2129, -4.6621]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-5.5420, -2.3104],
#         [-5.5420, -2.3104],
#         [ 0.7880, -3.6891],
#         [ 0.7880, -3.6891],
#         [ 1.3625, -4.4689],
#         [ 1.3625, -4.4689]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.0551, -3.1717],
#         [ 0.0551, -3.1717],
#         [-4.4999, -6.7278],
#         [-4.4999, -6.7278],
#         [-4.4999, -6.7278]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.4081, -2.4786],
#         [-5.2812, -1.7011],
#         [-5.2812, -1.7011],
#         [-5.2812, -1.7011],
#         [-5.2812, -1.7011]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.0763, -3.2353],
#         [ 0.0763, -3.2353],
#         [-4.4787, -6.7914],
#         [-4.4787, -6.7914],
#         [-4.4787, -6.7914]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.3869, -2.5422],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 0.0763, -3.2353],
#         [ 0.0763, -3.2353],
#         [-4.4787, -6.7914],
#         [-4.4787, -6.7914],
#         [-4.4787, -6.7914]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-5.3869, -2.5422],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647],
#         [-5.2600, -1.7647]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-5.1702, -1.7011],
#         [-4.1208, -1.2429],
#         [ 0.7782, -1.2961],
#         [-1.1793, -1.6279],
#         [-1.1793, -1.6279]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ -1.5090, -11.2339],
#         [  0.3100, -13.5939],
#         [  0.3100, -13.5939],
#         [  1.0485, -14.0947],
#         [  1.0485, -14.0947]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-5.1490, -1.7647],
#         [-4.0996, -1.3066],
#         [ 0.7994, -1.3597],
#         [-1.1581, -1.6916],
#         [-1.1581, -1.6916]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ -1.4878, -11.2975],
#         [  0.3312, -13.6576],
#         [  0.3312, -13.6576],
#         [  1.0697, -14.1583],
#         [  1.0697, -14.1583]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-5.1490, -1.7647],
#         [-4.0996, -1.3066],
#         [ 0.7994, -1.3597],
#         [-1.1581, -1.6916],
#         [-1.1581, -1.6916]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ -1.4878, -11.2975],
#         [  0.3312, -13.6576],
#         [  0.3312, -13.6576],
#         [  1.0697, -14.1583],
#         [  1.0697, -14.1583],
#         [  1.0697, -14.1583]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[  2.8117,  -5.9898],
#         [  2.8117,  -5.9898],
#         [  3.1560, -11.7838],
#         [  4.9830, -11.7293],
#         [  4.9830, -11.7293]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-2.7107, -2.3948],
#         [-2.7107, -2.3948],
#         [-3.1463, -0.9554],
#         [-3.1463, -0.9554],
#         [-3.5333, -0.9166]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[  2.8329,  -6.0534],
#         [  2.8329,  -6.0534],
#         [  3.1772, -11.8475],
#         [  5.0042, -11.7929],
#         [  5.0042, -11.7929]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-2.6895, -2.4584],
#         [-2.6895, -2.4584],
#         [-3.1251, -1.0190],
#         [-3.1251, -1.0190],
#         [-3.5121, -0.9803]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[  2.8329,  -6.0534],
#         [  2.8329,  -6.0534],
#         [  3.1772, -11.8475],
#         [  5.0042, -11.7929],
#         [  5.0042, -11.7929]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-2.6895, -2.4584],
#         [-2.6895, -2.4584],
#         [-3.1251, -1.0190],
#         [-3.1251, -1.0190],
#         [-3.5121, -0.9803],
#         [-3.5121, -0.9803]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-3.4146, -1.3921],
#         [-4.5979, -1.5801],
#         [-4.5608, -1.5453],
#         [-4.3622, -1.6711],
#         [-4.3622, -1.6711]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-1.7380, -1.4103],
#         [-1.7380, -1.4103],
#         [-1.7380, -1.4103],
#         [-0.8985, -1.2565],
#         [-0.8985, -1.2565]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-3.3934, -1.4557],
#         [-4.5767, -1.6438],
#         [-4.5396, -1.6089],
#         [-4.3410, -1.7348],
#         [-4.3410, -1.7348]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-1.7168, -1.4740],
#         [-1.7168, -1.4740],
#         [-1.7168, -1.4740],
#         [-0.8773, -1.3201],
#         [-0.8773, -1.3201]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-3.3934, -1.4557],
#         [-4.5767, -1.6438],
#         [-4.5396, -1.6089],
#         [-4.3410, -1.7348],
#         [-4.3410, -1.7348]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-1.7168, -1.4740],
#         [-1.7168, -1.4740],
#         [-1.7168, -1.4740],
#         [-0.8773, -1.3201],
#         [-0.8773, -1.3201],
#         [-0.8773, -1.3201]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-0.7965, -1.2565],
#         [-3.1203, -1.4665],
#         [-1.9208, -1.4153],
#         [-3.1611, -0.7189],
#         [-3.1611, -0.7189]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[1.8390, 3.9944],
#         [1.8390, 3.9944],
#         [1.8390, 3.9944],
#         [1.8390, 3.9944],
#         [1.8390, 3.9944]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-0.7754, -1.3201],
#         [-3.0991, -1.5302],
#         [-1.8997, -1.4789],
#         [-3.1399, -0.7826],
#         [-3.1399, -0.7826]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-0.7754, -1.3201],
#         [-3.0991, -1.5302],
#         [-1.8997, -1.4789],
#         [-3.1399, -0.7826],
#         [-3.1399, -0.7826]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308],
#         [1.8602, 3.9308]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-1.5019,  3.5966],
#         [-1.5019,  3.5966],
#         [-1.3118, -0.1106],
#         [-0.7890, -1.5355],
#         [-0.7890, -1.5355]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.7261,  9.0691],
#         [-6.2092,  6.9951],
#         [-6.2092,  6.9951],
#         [-2.7109,  8.6017],
#         [-2.7109,  8.6017]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-1.4807,  3.5330],
#         [-1.4807,  3.5330],
#         [-1.2906, -0.1742],
#         [-0.7678, -1.5992],
#         [-0.7678, -1.5992]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.7050,  9.0055],
#         [-6.1881,  6.9315],
#         [-6.1881,  6.9315],
#         [-2.6897,  8.5380],
#         [-2.6897,  8.5380]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-1.4807,  3.5330],
#         [-1.4807,  3.5330],
#         [-1.2906, -0.1742],
#         [-0.7678, -1.5992],
#         [-0.7678, -1.5992]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-5.7050,  9.0055],
#         [-6.1881,  6.9315],
#         [-6.1881,  6.9315],
#         [-2.6897,  8.5380],
#         [-2.6897,  8.5380],
#         [-2.6897,  8.5380]], grad_fn=<SliceBackward0>)
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-2.4378,  8.6017],
#         [-2.3007,  8.0078],
#         [ 0.0690,  9.6723],
#         [-0.3735,  7.1447],
#         [-0.3735,  7.1447]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.6365,  1.7161],
#         [-0.4594,  0.9690],
#         [-1.3048,  0.7772],
#         [-1.3048,  0.7772],
#         [ 0.2447, -0.3922]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-2.4166,  8.5381],
#         [-2.2796,  7.9441],
#         [ 0.0902,  9.6086],
#         [-0.3524,  7.0811],
#         [-0.3524,  7.0811]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.6577,  1.6525],
#         [-0.4382,  0.9054],
#         [-1.2836,  0.7136],
#         [-1.2836,  0.7136],
#         [ 0.2659, -0.4558]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-2.4166,  8.5381],
#         [-2.2796,  7.9441],
#         [ 0.0902,  9.6086],
#         [-0.3524,  7.0811],
#         [-0.3524,  7.0811]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 0.6577,  1.6525],
#         [-0.4382,  0.9054],
#         [-1.2836,  0.7136],
#         [-1.2836,  0.7136],
#         [ 0.2659, -0.4558],
#         [ 0.2659, -0.4558]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.4956, -1.4974],
#         [ 0.4956, -1.4974],
#         [ 0.0444, -0.6172],
#         [-0.1126, -2.0303],
#         [-0.1126, -2.0303]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.1077,  6.9416],
#         [-3.0765,  3.9985],
#         [-3.0765,  3.9985],
#         [-3.0765,  3.9985],
#         [-3.0765,  3.9985]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.5168, -1.5610],
#         [ 0.5168, -1.5610],
#         [ 0.0656, -0.6808],
#         [-0.0914, -2.0940],
#         [-0.0914, -2.0940]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.1288,  6.8780],
#         [-3.0553,  3.9348],
#         [-3.0553,  3.9348],
#         [-3.0553,  3.9348],
#         [-3.0553,  3.9348]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 0.5168, -1.5610],
#         [ 0.5168, -1.5610],
#         [ 0.0656, -0.6808],
#         [-0.0914, -2.0940],
#         [-0.0914, -2.0940]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 0.1288,  6.8780],
#         [-3.0553,  3.9348],
#         [-3.0553,  3.9348],
#         [-3.0553,  3.9348],
#         [-3.0553,  3.9348],
#         [-3.5300,  3.5104]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-3.0537,  3.5741],
#         [-4.3914,  8.3677],
#         [ 3.5159,  5.2092],
#         [ 3.5159,  5.2092],
#         [ 1.5400,  4.5848]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-2.9279, -1.2803],
#         [-2.9279, -1.2803],
#         [-2.9279, -1.2803],
#         [-2.9279, -1.2803],
#         [-2.9279, -1.2803]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-3.0326,  3.5105],
#         [-4.3703,  8.3041],
#         [ 3.5370,  5.1455],
#         [ 3.5370,  5.1455],
#         [ 1.5611,  4.5212]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-2.9068, -1.3439]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-3.0326,  3.5105],
#         [-4.3703,  8.3041],
#         [ 3.5370,  5.1455],
#         [ 3.5370,  5.1455],
#         [ 1.5611,  4.5212]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-2.9068, -1.3439],
#         [-0.1640, -0.4064]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-0.3643, -0.4525],
#         [-0.3643, -0.4525],
#         [-2.6457,  2.8509],
#         [-1.4289, -0.4722],
#         [-1.4289, -0.4722]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.3547,  1.7169],
#         [ 0.3547,  1.7169],
#         [-0.3090,  1.4075],
#         [ 0.5894,  2.0289],
#         [ 0.5894,  2.0289]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-0.3432, -0.5161],
#         [-0.3432, -0.5161],
#         [-2.6246,  2.7873],
#         [-1.4078, -0.5359],
#         [-1.4078, -0.5359]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.3758,  1.6532],
#         [ 0.3758,  1.6532],
#         [-0.2878,  1.3438],
#         [ 0.6105,  1.9652],
#         [ 0.6105,  1.9652]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-0.3432, -0.5161],
#         [-0.3432, -0.5161],
#         [-2.6246,  2.7873],
#         [-1.4078, -0.5359],
#         [-1.4078, -0.5359]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 0.3758,  1.6532],
#         [ 0.3758,  1.6532],
#         [-0.2878,  1.3438],
#         [ 0.6105,  1.9652],
#         [ 0.6105,  1.9652],
#         [ 0.6105,  1.9652]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.2023,  1.4007],
#         [ 0.8051,  3.6653],
#         [-1.0351,  1.1081],
#         [-0.9921,  1.9215],
#         [-0.9921,  1.9215]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 2.1766,  6.5986],
#         [ 2.1766,  6.5986],
#         [-0.7029,  7.2540],
#         [-0.7029,  7.2540],
#         [-0.0296,  3.2054]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.2235,  1.3371],
#         [ 0.8262,  3.6016],
#         [-1.0139,  1.0445],
#         [-0.9710,  1.8578],
#         [-0.9710,  1.8578]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 2.1977,  6.5349],
#         [ 2.1977,  6.5349],
#         [-0.6818,  7.1903],
#         [-0.6818,  7.1903],
#         [-0.0085,  3.1418]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 0.2235,  1.3371],
#         [ 0.8262,  3.6016],
#         [-1.0139,  1.0445],
#         [-0.9710,  1.8578],
#         [-0.9710,  1.8578]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 2.1977,  6.5349],
#         [ 2.1977,  6.5349],
#         [-0.6818,  7.1903],
#         [-0.6818,  7.1903],
#         [-0.0085,  3.1418],
#         [-0.0085,  3.1418]], grad_fn=<SliceBackward0>)

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2)  # Single layer nn for Lin Regr

trained_model_streamed10, loss_log_streamed10 = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, compare_model_and_matmul=True, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=10,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_streamed10)), loss_log_streamed10, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 10-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 10
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-17.7185,   4.2721],
#         [-17.7185,   4.2721],
#         [-24.1804,   9.6640],
#         [-27.2540,  10.4636],
#         [-27.2540,  10.4636]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-20.2917,  11.3769],
#         [-20.8464,  11.3476],
#         [-20.8464,  11.3476],
#         [-22.8305,  13.5717],
#         [-22.8305,  13.5717]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-17.7810,   4.2041],
#         [-17.7810,   4.2041],
#         [-24.2429,   9.5961],
#         [-27.3165,  10.3956],
#         [-27.3165,  10.3956]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-20.3542,  11.3089],
#         [-20.9089,  11.2796],
#         [-20.9089,  11.2796],
#         [-22.8930,  13.5037],
#         [-22.8930,  13.5037]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-17.7810,   4.2041],
#         [-17.7810,   4.2041],
#         [-24.2429,   9.5961],
#         [-27.3165,  10.3956],
#         [-27.3165,  10.3956]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-20.3542,  11.3089],
#         [-20.9089,  11.2796],
#         [-20.9089,  11.2796],
#         [-22.8930,  13.5037],
#         [-22.8930,  13.5037],
#         [-22.8930,  13.5037]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-16.9492,  13.5733],
#         [-18.1342,  12.7140],
#         [-20.0927,  13.1305],
#         [-19.7018,   9.5449],
#         [-19.7018,   9.5449]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-6.8551,  3.2897],
#         [-8.1915,  3.4055],
#         [-6.5367,  3.1898],
#         [-6.5367,  3.1898],
#         [-6.8754,  4.6254]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-17.0118,  13.5053],
#         [-18.1968,  12.6461],
#         [-20.1553,  13.0626],
#         [-19.7645,   9.4769],
#         [-19.7645,   9.4769]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-6.9177,  3.2218],
#         [-8.2541,  3.3375],
#         [-6.5994,  3.1218],
#         [-6.5994,  3.1218],
#         [-6.9380,  4.5574]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-17.0118,  13.5053],
#         [-18.1968,  12.6461],
#         [-20.1553,  13.0626],
#         [-19.7645,   9.4769],
#         [-19.7645,   9.4769]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-6.9177,  3.2218],
#         [-8.2541,  3.3375],
#         [-6.5994,  3.1218],
#         [-6.5994,  3.1218],
#         [-6.9380,  4.5574],
#         [-6.9380,  4.5574]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-4.2141,  4.1940],
#         [-4.2141,  4.1940],
#         [-3.2691,  4.4086],
#         [-3.9188,  4.0874],
#         [-3.9188,  4.0874]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-12.1085,  12.0015],
#         [-12.6305,  12.1966],
#         [-12.6305,  12.1966],
#         [-12.6305,  12.1966],
#         [-12.6305,  12.1966]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-4.2768,  4.1261],
#         [-4.2768,  4.1261],
#         [-3.3318,  4.3406],
#         [-3.9815,  4.0194],
#         [-3.9815,  4.0194]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-12.1712,  11.9335],
#         [-12.6932,  12.1287],
#         [-12.6932,  12.1287],
#         [-12.6932,  12.1287],
#         [-12.6932,  12.1287]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-4.2768,  4.1261],
#         [-4.2768,  4.1261],
#         [-3.3318,  4.3406],
#         [-3.9815,  4.0194],
#         [-3.9815,  4.0194]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-12.1712,  11.9335],
#         [-12.6932,  12.1287],
#         [-12.6932,  12.1287],
#         [-12.6932,  12.1287],
#         [-12.6932,  12.1287],
#         [-14.2332,  13.8191]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-11.5963,  13.8878],
#         [ -7.5785,  11.4972],
#         [ -2.5775,   9.7703],
#         [ -2.5775,   9.7703],
#         [ -4.8411,  10.7354]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-10.1589,   3.8034],
#         [-10.1589,   3.8034],
#         [-10.1589,   3.8034],
#         [-10.1589,   3.8034],
#         [-10.1589,   3.8034]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-11.6591,  13.8198],
#         [ -7.6413,  11.4292],
#         [ -2.6403,   9.7024],
#         [ -2.6403,   9.7024],
#         [ -4.9038,  10.6674]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-10.2216,   3.7355]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-11.6591,  13.8198],
#         [ -7.6413,  11.4292],
#         [ -2.6403,   9.7024],
#         [ -2.6403,   9.7024],
#         [ -4.9038,  10.6674]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-10.2216,   3.7355],
#         [-11.2338,   0.3548]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-10.8753,  -0.8174],
#         [-10.8753,  -0.8174],
#         [ -9.7206,   3.5549],
#         [ -8.3371,   2.1939],
#         [ -8.3371,   2.1939]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-3.7941,  5.4268],
#         [-3.7941,  5.4268],
#         [-3.4844,  4.5755],
#         [-5.9610,  7.6682],
#         [-5.9610,  7.6682]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-10.9381,  -0.8854],
#         [-10.9381,  -0.8854],
#         [ -9.7834,   3.4869],
#         [ -8.3999,   2.1259],
#         [ -8.3999,   2.1259]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-3.8569,  5.3589],
#         [-3.8569,  5.3589],
#         [-3.5472,  4.5075],
#         [-6.0238,  7.6002],
#         [-6.0238,  7.6002]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-10.9381,  -0.8854],
#         [-10.9381,  -0.8854],
#         [ -9.7834,   3.4869],
#         [ -8.3999,   2.1259],
#         [ -8.3999,   2.1259]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-3.8569,  5.3589],
#         [-3.8569,  5.3589],
#         [-3.5472,  4.5075],
#         [-6.0238,  7.6002],
#         [-6.0238,  7.6002],
#         [-6.0238,  7.6002]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-4.2012,  5.6470],
#         [-3.6363,  6.4903],
#         [-2.6343,  3.3345],
#         [-3.1339,  2.8930],
#         [-3.1339,  2.8930]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-6.6055,  8.0313],
#         [-6.6055,  8.0313],
#         [-4.8770,  4.9149],
#         [-4.8770,  4.9149],
#         [-6.4302,  3.9294]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-4.2641,  5.5791],
#         [-3.6991,  6.4223],
#         [-2.6972,  3.2665],
#         [-3.1967,  2.8250],
#         [-3.1967,  2.8250]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-6.6684,  7.9634],
#         [-6.6684,  7.9634],
#         [-4.9399,  4.8469],
#         [-4.9399,  4.8469],
#         [-6.4931,  3.8615]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-4.2641,  5.5791],
#         [-3.6991,  6.4223],
#         [-2.6972,  3.2665],
#         [-3.1967,  2.8250],
#         [-3.1967,  2.8250]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-6.6684,  7.9634],
#         [-6.6684,  7.9634],
#         [-4.9399,  4.8469],
#         [-4.9399,  4.8469],
#         [-6.4931,  3.8615],
#         [-6.4931,  3.8615]], grad_fn=<SliceBackward0>)

# %% [markdown]
# ## Redoing but turning PyTorch model bias off

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2, bias=False)  # Single layer nn for Lin Regr
optimizer = torch.optim.SGD(untrained_model_FullData.parameters(), lr=learning_rate)

trained_model_FullData, loss_log_FullData = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, compare_model_and_matmul=True, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=False, use_full_input_data=True, starting_update=0,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_FullData)), loss_log_FullData, linewidth=3)
plt.title("Training Loss On Nonstreamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data True
# stream_data_updates False
# return_cost_func_comps False
#
# v_pred_model shape: torch.Size([19228, 2]);
#  vals[:5,:]: tensor([[ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [-0.5412, -0.5631],
#         [-0.5412, -0.5631]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-20.2978,   8.5369],
#         [-20.2978,   8.5369],
#         [-20.2978,   8.5369],
#         [-19.5296,   5.7774],
#         [-19.5296,   5.7774]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([19228, 2]);
#  vals[:5,:]: tensor([[ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [-0.5412, -0.5631],
#         [-0.5412, -0.5631]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-20.2978,   8.5369],
#         [-20.2978,   8.5369],
#         [-20.2978,   8.5369],
#         [-19.5296,   5.7774],
#         [-19.5296,   5.7774]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([19229, 2]);
#  vals[:5,:]: tensor([[ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [-0.5412, -0.5631],
#         [-0.5412, -0.5631]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-20.2978,   8.5369],
#         [-20.2978,   8.5369],
#         [-20.2978,   8.5369],
#         [-19.5296,   5.7774],
#         [-19.5296,   5.7774],
#         [-16.3940,   6.1340]], grad_fn=<SliceBackward0>)

# %%
# Other option which should give same result:
untrained_model_FullData = torch.nn.Linear(64, 2, bias=False)  # Single layer nn for Lin Regr

trained_model_streamed, loss_log_streamed = full_train_linregr_updates(untrained_model_FullData, cli0_cond1_traindata, cli0_cond1_trainlabels, learning_rate, 
                                                                       num_iters_per_update=30, compare_model_and_matmul=True, lambdasFDE=[lambdaF, lambdaD, lambdaE], 
                                                                       stream_data_updates=True, use_full_input_data=False, starting_update=0,
                                                                       use_CPHSLoss2=True)

plt.plot(range(len(loss_log_streamed)), loss_log_streamed, linewidth=3)
plt.title("Training Loss On Streamed Training Data [Updates 0-16]")
plt.xlabel('Iteration Number')
plt.ylabel('Cost L2')
plt.show()
# Out:
# full_train_linregr_updates Params:
# learning_rate 0.0001
# lambdasFDE [0, 1e-10, 1e-06]
# use_CPHSLoss False; use_CPHSLoss2 True
# normalize_emg False
# num_iters_per_update 30
# starting_update 0
# use_full_input_data False
# stream_data_updates True
# return_cost_func_comps False
#
# v_pred_model shape: torch.Size([1199, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.8090, 1.7392],
#         [0.8090, 1.7392]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[10.0233, -3.3328],
#         [10.0233, -3.3328],
#         [10.6416, -2.8425],
#         [10.6416, -2.8425],
#         [10.6416, -2.8425]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1199, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.8090, 1.7392],
#         [0.8090, 1.7392]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[10.0233, -3.3328],
#         [10.0233, -3.3328],
#         [10.6416, -2.8425],
#         [10.6416, -2.8425],
#         [10.6416, -2.8425]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1200, 2]);
#  vals[:5,:]: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.8090, 1.7392],
#         [0.8090, 1.7392]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[10.0233, -3.3328],
#         [10.0233, -3.3328],
#         [10.6416, -2.8425],
#         [10.6416, -2.8425],
#         [10.6416, -2.8425],
#         [12.0676, -3.6111]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[10.8741, -6.4400],
#         [10.8741, -6.4400],
#         [ 7.7185, -8.8467],
#         [ 8.4370, -6.3653],
#         [ 7.9921, -4.8079]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[38.8392, 38.0766],
#         [38.8392, 38.0766],
#         [46.7160, 44.3709],
#         [46.7160, 44.3709],
#         [46.7160, 44.3709]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[10.8741, -6.4400],
#         [10.8741, -6.4400],
#         [ 7.7185, -8.8467],
#         [ 8.4370, -6.3653],
#         [ 7.9921, -4.8079]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[38.8392, 38.0765],
#         [38.8392, 38.0765],
#         [46.7160, 44.3708],
#         [46.7160, 44.3708],
#         [46.7160, 44.3709]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[10.8741, -6.4400],
#         [10.8741, -6.4400],
#         [ 7.7185, -8.8467],
#         [ 8.4370, -6.3653],
#         [ 7.9921, -4.8079]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[38.8392, 38.0765],
#         [38.8392, 38.0765],
#         [46.7160, 44.3708],
#         [46.7160, 44.3709],
#         [46.7160, 44.3709],
#         [46.7160, 44.3709]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[43.7833, 45.0289],
#         [43.7833, 45.0289],
#         [42.1322, 31.4340],
#         [39.9571, 23.4105],
#         [39.9571, 23.4105]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 1.4556,  9.1201],
#         [ 1.4556,  9.1201],
#         [ 1.0085, 11.5438],
#         [ 1.0085, 11.5438],
#         [-0.3457, 11.5868]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[43.7833, 45.0289],
#         [43.7833, 45.0289],
#         [42.1322, 31.4340],
#         [39.9571, 23.4105],
#         [39.9571, 23.4105]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 1.4556,  9.1201],
#         [ 1.4556,  9.1201],
#         [ 1.0085, 11.5438],
#         [ 1.0085, 11.5438],
#         [-0.3457, 11.5868]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[43.7833, 45.0289],
#         [43.7833, 45.0289],
#         [42.1322, 31.4340],
#         [39.9571, 23.4105],
#         [39.9571, 23.4105]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 1.4556,  9.1201],
#         [ 1.4556,  9.1201],
#         [ 1.0085, 11.5438],
#         [ 1.0085, 11.5438],
#         [-0.3457, 11.5868],
#         [-0.3457, 11.5868]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-3.1752, 11.5860],
#         [-3.1752, 11.5860],
#         [ 2.3043,  7.0858],
#         [ 2.2058,  6.4991],
#         [ 2.2058,  6.4991]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-12.5147,  19.9385],
#         [-12.5147,  19.9385],
#         [-13.7311,  25.8042],
#         [-13.7311,  25.8042],
#         [-14.3736,  26.6752]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-3.1752, 11.5860],
#         [-3.1752, 11.5860],
#         [ 2.3043,  7.0858],
#         [ 2.2058,  6.4991],
#         [ 2.2058,  6.4991]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-12.5147,  19.9385],
#         [-12.5147,  19.9385],
#         [-13.7311,  25.8042],
#         [-13.7311,  25.8042],
#         [-14.3736,  26.6752]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-3.1752, 11.5860],
#         [-3.1752, 11.5860],
#         [ 2.3043,  7.0858],
#         [ 2.2058,  6.4991],
#         [ 2.2058,  6.4991]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-12.5147,  19.9385],
#         [-12.5147,  19.9385],
#         [-13.7311,  25.8042],
#         [-13.7311,  25.8042],
#         [-14.3736,  26.6752],
#         [-14.3736,  26.6752]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-21.9497,  32.4557],
#         [-21.9497,  32.4557],
#         [-15.9659,  22.4320],
#         [-12.7036,  23.2306],
#         [-12.7036,  23.2306]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[1.6403, 0.6220],
#         [1.6403, 0.6220],
#         [1.7756, 5.3336],
#         [1.7756, 5.3336],
#         [2.5813, 6.2658]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-21.9497,  32.4557],
#         [-21.9497,  32.4557],
#         [-15.9659,  22.4320],
#         [-12.7036,  23.2306],
#         [-12.7036,  23.2306]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[1.6403, 0.6220],
#         [1.6403, 0.6220],
#         [1.7756, 5.3336],
#         [1.7756, 5.3336],
#         [2.5813, 6.2658]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-21.9497,  32.4557],
#         [-21.9497,  32.4557],
#         [-15.9659,  22.4320],
#         [-12.7036,  23.2306],
#         [-12.7036,  23.2306]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[1.6403, 0.6220],
#         [1.6403, 0.6220],
#         [1.7756, 5.3336],
#         [1.7756, 5.3336],
#         [2.5813, 6.2658],
#         [2.5813, 6.2658]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 4.3962,  5.4979],
#         [ 4.3962,  5.4979],
#         [10.6168, -2.4523],
#         [10.6168, -2.4523],
#         [10.6168, -2.4523]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.2051, -0.7068],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 4.3962,  5.4979],
#         [ 4.3962,  5.4979],
#         [10.6168, -2.4523],
#         [10.6168, -2.4523],
#         [10.6168, -2.4523]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 0.2051, -0.7068],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 4.3962,  5.4979],
#         [ 4.3962,  5.4979],
#         [10.6168, -2.4523],
#         [10.6168, -2.4523],
#         [10.6168, -2.4523]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 0.2051, -0.7068],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563],
#         [ 1.0608, -0.0563]], grad_fn=<SliceBackward0>)
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 1.2941, -0.0563],
#         [ 2.3338, -0.6863],
#         [ 1.3157,  6.3564],
#         [-0.3378,  4.5652],
#         [-0.3378,  4.5652]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-7.2599,  2.5651],
#         [-7.6901,  2.6457],
#         [-7.6901,  2.6457],
#         [-8.8832,  3.2695],
#         [-8.8832,  3.2695]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 1.2941, -0.0563],
#         [ 2.3338, -0.6863],
#         [ 1.3157,  6.3564],
#         [-0.3378,  4.5652],
#         [-0.3378,  4.5652]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-7.2599,  2.5651],
#         [-7.6901,  2.6457],
#         [-7.6901,  2.6457],
#         [-8.8832,  3.2695],
#         [-8.8832,  3.2695]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 1.2941, -0.0563],
#         [ 2.3338, -0.6863],
#         [ 1.3157,  6.3564],
#         [-0.3378,  4.5652],
#         [-0.3378,  4.5652]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-7.2599,  2.5651],
#         [-7.6901,  2.6457],
#         [-7.6901,  2.6457],
#         [-8.8832,  3.2695],
#         [-8.8832,  3.2695],
#         [-8.8832,  3.2695]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ -9.1793,  10.7804],
#         [ -9.1793,  10.7804],
#         [-17.4166,  13.1698],
#         [-19.8225,  17.3149],
#         [-19.8225,  17.3149]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[2.5307, 5.6775],
#         [2.5307, 5.6775],
#         [2.1022, 5.6564],
#         [2.1022, 5.6564],
#         [0.4903, 4.1251]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ -9.1793,  10.7804],
#         [ -9.1793,  10.7804],
#         [-17.4166,  13.1698],
#         [-19.8225,  17.3149],
#         [-19.8225,  17.3149]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[2.5307, 5.6775],
#         [2.5307, 5.6775],
#         [2.1022, 5.6564],
#         [2.1022, 5.6564],
#         [0.4903, 4.1251]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ -9.1793,  10.7804],
#         [ -9.1793,  10.7804],
#         [-17.4166,  13.1698],
#         [-19.8225,  17.3149],
#         [-19.8225,  17.3149]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[2.5307, 5.6775],
#         [2.5307, 5.6775],
#         [2.1022, 5.6564],
#         [2.1022, 5.6564],
#         [0.4903, 4.1251],
#         [0.4903, 4.1251]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-0.9235,  4.2525],
#         [ 0.1542,  3.1399],
#         [ 0.4827,  2.0179],
#         [-0.1759,  0.3671],
#         [-0.1759,  0.3671]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[0.8360, 8.4255],
#         [0.8360, 8.4255],
#         [0.8360, 8.4255],
#         [1.1833, 9.6638],
#         [1.1833, 9.6638]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-0.9235,  4.2525],
#         [ 0.1542,  3.1399],
#         [ 0.4827,  2.0179],
#         [-0.1759,  0.3671],
#         [-0.1759,  0.3671]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[0.8360, 8.4255],
#         [0.8360, 8.4255],
#         [0.8360, 8.4255],
#         [1.1833, 9.6638],
#         [1.1833, 9.6638]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-0.9235,  4.2525],
#         [ 0.1542,  3.1399],
#         [ 0.4827,  2.0179],
#         [-0.1759,  0.3671],
#         [-0.1759,  0.3671]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[0.8360, 8.4255],
#         [0.8360, 8.4255],
#         [0.8360, 8.4255],
#         [1.1833, 9.6638],
#         [1.1833, 9.6638],
#         [1.1833, 9.6638]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.1068,  9.6635],
#         [ 0.1559,  6.3489],
#         [-1.2749,  7.7216],
#         [-0.8959,  5.9275],
#         [-0.8959,  5.9275]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 0.1068,  9.6635],
#         [ 0.1559,  6.3489],
#         [-1.2749,  7.7216],
#         [-0.8959,  5.9275],
#         [-0.8959,  5.9275]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 0.1068,  9.6635],
#         [ 0.1559,  6.3489],
#         [-1.2749,  7.7216],
#         [-0.8959,  5.9275],
#         [-0.8959,  5.9275]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972],
#         [ 9.9814, 20.7972]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 3.2288, 14.5393],
#         [ 3.2288, 14.5393],
#         [ 0.7797, 13.8144],
#         [ 2.5904, 12.9361],
#         [ 2.5904, 12.9361]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[11.3455,  9.6878],
#         [ 5.8760,  9.1666],
#         [ 5.8760,  9.1666],
#         [ 5.7563, 18.2534],
#         [ 5.7563, 18.2534]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 3.2288, 14.5393],
#         [ 3.2288, 14.5393],
#         [ 0.7797, 13.8144],
#         [ 2.5904, 12.9361],
#         [ 2.5904, 12.9361]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[11.3455,  9.6878],
#         [ 5.8760,  9.1666],
#         [ 5.8760,  9.1666],
#         [ 5.7563, 18.2534],
#         [ 5.7563, 18.2534]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 3.2288, 14.5393],
#         [ 3.2288, 14.5393],
#         [ 0.7797, 13.8144],
#         [ 2.5904, 12.9361],
#         [ 2.5904, 12.9361]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[11.3455,  9.6878],
#         [ 5.8760,  9.1666],
#         [ 5.8760,  9.1666],
#         [ 5.7563, 18.2534],
#         [ 5.7563, 18.2534],
#         [ 5.7563, 18.2534]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 5.0641, 18.2532],
#         [ 3.0048, 21.2345],
#         [ 2.5742, 20.3583],
#         [ 6.0775, 17.4543],
#         [ 6.0775, 17.4543]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-1.6047,  8.5458],
#         [-0.9203,  8.8188],
#         [-2.4734,  7.6957],
#         [-2.4734,  7.6957],
#         [-1.7836,  7.6554]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 5.0641, 18.2532],
#         [ 3.0048, 21.2345],
#         [ 2.5742, 20.3583],
#         [ 6.0775, 17.4543],
#         [ 6.0775, 17.4543]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-1.6047,  8.5458],
#         [-0.9203,  8.8188],
#         [-2.4734,  7.6957],
#         [-2.4734,  7.6957],
#         [-1.7836,  7.6554]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 5.0641, 18.2532],
#         [ 3.0048, 21.2345],
#         [ 2.5742, 20.3583],
#         [ 6.0775, 17.4543],
#         [ 6.0775, 17.4543]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-1.6047,  8.5458],
#         [-0.9203,  8.8188],
#         [-2.4734,  7.6957],
#         [-2.4734,  7.6957],
#         [-1.7836,  7.6554],
#         [-1.7836,  7.6554]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-1.7238,  6.8102],
#         [-1.7238,  6.8102],
#         [-2.4892,  6.8897],
#         [-2.6933,  6.2205],
#         [-2.6933,  6.2205]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 3.8134, 13.9579],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-1.7238,  6.8102],
#         [-1.7238,  6.8102],
#         [-2.4892,  6.8897],
#         [-2.6933,  6.2205],
#         [-2.6933,  6.2205]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 3.8134, 13.9579],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-1.7238,  6.8102],
#         [-1.7238,  6.8102],
#         [-2.4892,  6.8897],
#         [-2.6933,  6.2205],
#         [-2.6933,  6.2205]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 3.8134, 13.9579],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.4053,  8.5006],
#         [ 2.2621,  9.2412]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 2.3573,  9.2412],
#         [ 5.4049,  9.0263],
#         [ 1.3170, 16.8052],
#         [ 1.3170, 16.8052],
#         [ 1.8414, 16.0673]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[ 2.3573,  9.2412],
#         [ 5.4049,  9.0263],
#         [ 1.3170, 16.8052],
#         [ 1.3170, 16.8052],
#         [ 1.8414, 16.0673]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[ 2.3573,  9.2412],
#         [ 5.4049,  9.0263],
#         [ 1.3170, 16.8052],
#         [ 1.3170, 16.8052],
#         [ 1.8414, 16.0673]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-5.5188, 13.6459],
#         [-8.2468, 19.3918]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-6.9455, 18.3585],
#         [-6.9455, 18.3585],
#         [-7.6985, 20.1777],
#         [-2.7379, 16.2436],
#         [-2.7379, 16.2436]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 1.2829,  9.2941],
#         [ 1.2829,  9.2941],
#         [ 1.4934,  8.6595],
#         [-1.0363,  9.1212],
#         [-1.0363,  9.1212]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-6.9455, 18.3585],
#         [-6.9455, 18.3585],
#         [-7.6985, 20.1777],
#         [-2.7379, 16.2436],
#         [-2.7379, 16.2436]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 1.2829,  9.2941],
#         [ 1.2829,  9.2941],
#         [ 1.4934,  8.6595],
#         [-1.0363,  9.1212],
#         [-1.0363,  9.1212]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-6.9455, 18.3585],
#         [-6.9455, 18.3585],
#         [-7.6985, 20.1777],
#         [-2.7379, 16.2436],
#         [-2.7379, 16.2436]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 1.2829,  9.2941],
#         [ 1.2829,  9.2941],
#         [ 1.4934,  8.6595],
#         [-1.0363,  9.1212],
#         [-1.0363,  9.1212],
#         [-1.0363,  9.1212]], grad_fn=<SliceBackward0>)
#
#
# v_pred_model shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-1.2211,  8.1928],
#         [-0.9133, 10.0678],
#         [ 1.4071,  7.7373],
#         [ 0.7296,  9.8424],
#         [ 0.7296,  9.8424]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 7.8607, 16.3246],
#         [ 7.8607, 16.3246],
#         [ 4.0464, 14.8281],
#         [ 4.0464, 14.8281],
#         [ 1.1413, 12.5290]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul shape: torch.Size([1201, 2]);
#  vals[:5,:]: tensor([[-1.2211,  8.1928],
#         [-0.9133, 10.0678],
#         [ 1.4071,  7.7373],
#         [ 0.7296,  9.8424],
#         [ 0.7296,  9.8424]], grad_fn=<SliceBackward0>);
#  vals[-5:,:]: tensor([[ 7.8607, 16.3246],
#         [ 7.8607, 16.3246],
#         [ 4.0464, 14.8281],
#         [ 4.0464, 14.8281],
#         [ 1.1413, 12.5290]], grad_fn=<SliceBackward0>)
# ---------------------------------------
# v_pred_matmul_s shape: torch.Size([1202, 2]);
#  vals[:5,:]: tensor([[-1.2211,  8.1928],
#         [-0.9133, 10.0678],
#         [ 1.4071,  7.7373],
#         [ 0.7296,  9.8424],
#         [ 0.7296,  9.8424]], grad_fn=<SliceBackward0>);
#  vals[-6:,:]: tensor([[ 7.8607, 16.3246],
#         [ 7.8607, 16.3246],
#         [ 4.0464, 14.8281],
#         [ 4.0464, 14.8281],
#         [ 1.1413, 12.5290],
#         [ 1.1413, 12.5290]], grad_fn=<SliceBackward0>)
